# %% [markdown]
# # Webscraping Group Challenges

# %% [markdown]
# ## 1. Twitter
# - Apply your knowledge from the workshop and obtain data from the Twitter API that will be insightful, e.g. w.r.t. demographics, spatial distribution or focussing on the time domain.
# - Visualise your dataset appropriately and write a summary/description that explains the project to a *5-year-old child* including which technologies/libraries/methods you used, which steps were involved and which challenges/problems you ran into.
#
# **Difficulty: do-able**

# %% [markdown]
# ## 2. Spotify
# - Apply your knowledge from the workshop and demonstrate how you can combine multiple data sources in order to construct novel datasets. For example, you can use static HTML scraping in order to obtain relevant information from the [Spotify Charts Website](https://spotifycharts.com/regional) which provides the absolute number of music streams of individual tracks on a daily and/or weekly basis (along with their `track ids`).
# - Use those `track ids` as inputs to query the Spotify API through its Python implementation [`spotipy`](https://spotipy.readthedocs.io/en/2.18.0/)(https://spotipy.readthedocs.io/en/2.18.0/). You can check for example the [`audio_features()`](https://developer.spotify.com/console/get-audio-features-track/) function which informs about the psycho-acoustical properties of a music/audio track (e.g. `speechiness`, `energy` and `valence` which measures the 'sadness' of a song). You can also try those requests first in a *sandbox* before implementing it, e.g. here: https://developer.spotify.com/console/get-audio-features-track/.
# - Visualise your dataset appropriately and write a summary/description that explains the project to a *5-year-old child* including which technologies/libraries/methods you used, which steps were involved and which challenges/problems you ran into.
#
# **Difficulty: challenging but do-able** - *you might want to solve the challenge only partially*

# %% [markdown]
# ## 3. Corona Data (RKI)
# - Apply your knowledge from the workshop and demonstrate how you can combine multiple data sources in order to construct novel datasets. For example, you can obtain the entire history registered Corona *cases* (i.e. infected people) in Germany from the RKI GIS Service [here](https://opendata.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0.geojson) which can be readily read into Python via `geopandas`. Note that the raw data structure requires **heavy** aggregation.
# - If you do not manage to restructure the raw data set you can directly read in an [intermediate dataset](https://gist.githubusercontent.com/gerwolf/a8994144f8836c58fe5620a0f96aa2f1/raw/64ebd0823eb51a25b402b60a90a4e0a78bec7010/Complete_days_landkreis.csv) (in `.csv` format using e.g. `pandas.read_csv()`) that I prepared for you based on the original source above (but note that the observations start on the date where the pandemic reached **all** counties, which was on 20/03/2021 and hence the virus needed only 73 days to spread from the first registered case in Cologne across any county).
# - You might want to combine this dataset with external joins from sources such as the Destatis/GENESIS Online API (e.g. use the `RS` field from the dataset above). Also, drop all weekend days since on weekends no registrations are being made and submitted.
# - Visualise your dataset appropriately (in an interactive map) and write a summary/description that explains the project to a *5-year-old child* including which technologies/libraries/methods you used, which steps were involved and which challenges/problems you ran into.
#
# **Difficulty: very difficult** - *more experienced Python users and some background knowledge in GIS*

# %% [markdown]
# ## 4: ?
# You're welcome to come up with an own idea if it allows you to demonstrate the techniques you have learned in the workshop.

# %%
from IPython.display import Image
Image("https://media.giphy.com/media/4GXUa4U05Q0JAM972c/giphy.gif")
